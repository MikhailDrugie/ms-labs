# %% [markdown]
# # Лабораторная работа №6
#
# # Построение пайплайна одномерной регрессии
#
# ## Подключение библиотек

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Загрузка данных и разделение на матрицу признаков и зависимую переменную
#
# Данные сгенерированы на mockaroo по формулам:
# - Years: random(1, 15, decimals=1)
# - Salary: random(15000, 45000, decimals=0) + Years * random(10000, 15000)

# %%
dataset = pd.read_csv('salaries.data.csv')
dataset.head()
# Out:
#    Years    Salary
# 0    1.6   59364.6
# 1   11.9  198979.6
# 2    7.6  125987.4
# 3   10.7  169469.0
# 4    7.8  119498.6

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values
print ("Матрица признаков"); print(X[:5])
print ("Зависимая переменная"); print(y[:5])
# Out:
# Матрица признаков
# [[ 1.6]
#  [11.9]
#  [ 7.6]
#  [10.7]
#  [ 7.8]]
# Зависимая переменная
# [ 59364.6 198979.6 125987.4 169469.  119498.6]

# %% [markdown]
# ## Разделение выборки на тестовую и тренировочную

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.05, random_state = 0)

# %% [markdown]
# ## Обучение линейной модели регрессии

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Предсказание, обработка и визуализация результатов

# %%
y_pred = regressor.predict(X_test)
print(y_pred)
# Out:
# [ 51746.18944645  91671.27831983 157797.20676637  86680.64221066
#  131596.36719322  48003.21236457  48003.21236457 122862.75400216
#  127853.39011134 106643.18664735 119119.77692029 114129.14081111
#  172769.11509389  95414.25540171 144072.95746615 186493.36439412
#   96661.91442901  43012.5762554   44260.23528269 101652.55053818
#  101652.55053818 197722.29563976 114129.14081111 201465.27272164
#  102900.20956547  96661.91442901 107890.84567465 170273.79703931
#  198969.95466705 179007.41023036 150311.25260262 106643.18664735
#  115376.79983841 110386.16372923  61727.4616648   87928.30123795
#   80442.3470742  171521.4560666  176512.09217577 176512.09217577
#  116624.4588657  144072.95746615 169026.13801201 198969.95466705
#  207703.5678581  135339.3442751  150311.25260262 172769.11509389
#  201465.27272164 172769.11509389]

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
